# %%
import matplotlib.pyplot as plt
import numpy as np
import sys, os
sys.path.append(os.pardir)
sys.path.append("../../")
from sklearn.datasets import load_iris
from logisticReg import Lreg

# %%
iris = load_iris()
X = iris.data
iris_Y = iris.target

Y = iris_Y.copy()

# 원 핫 인코딩
num = np.unique(Y,axis=0)
num = num.shape[0]
Y = np.eye(num)[Y].astype(np.int)

y_name = iris.target_names
print("feature 수: ",X.shape[1])
# Out:
# feature 수:  4

# %%
# 인덱스 suffle
suffle_mask = np.random.choice(X.shape[0],X.shape[0],replace=False)

# data 80퍼센트는 Train용, 20퍼센트는 Test용
bound = int(0.8 * X.shape[0])

x_train = X[suffle_mask[:bound]]
x_test = X[suffle_mask[bound:]]
y_train = Y[suffle_mask[:bound]]
y_test = Y[suffle_mask[bound:]]

# %%
# feature * class 수 = 4*3 weight layer + bias 
reg = Lreg(X.shape[1],y_name.shape[0],"m")

# %%
reg.reset_weight()
reg.learn(x_train,y_train,epoch=200,batch_size=120,lr=0.07)
# Out:
# Before Learning:
# | Train_Accuracy: 0.35 | COST: [0.471 4.188 4.306]
# 1
# | Train_Accuracy: 0.35 | COST: [0.452 2.554 3.791]
# 2
# | Train_Accuracy: 0.35 | COST: [0.433 1.146 3.301]
# 3
# | Train_Accuracy: 0.43333333333333335 | COST: [0.416 0.703 2.863]
# 4
# | Train_Accuracy: 0.5083333333333333 | COST: [0.400 0.692 2.514]
# 5
# | Train_Accuracy: 0.4 | COST: [0.385 0.684 2.258]
# 6
# | Train_Accuracy: 0.35 | COST: [0.371 0.677 2.067]
# 7
# | Train_Accuracy: 0.35 | COST: [0.358 0.670 1.916]
# 8
# | Train_Accuracy: 0.35 | COST: [0.346 0.663 1.792]
# 9
# | Train_Accuracy: 0.35 | COST: [0.334 0.657 1.689]
# 10
# | Train_Accuracy: 0.35 | COST: [0.323 0.651 1.602]
# 11
# | Train_Accuracy: 0.35 | COST: [0.313 0.646 1.526]
# 12
# | Train_Accuracy: 0.35 | COST: [0.303 0.641 1.457]
# 13
# | Train_Accuracy: 0.35 | COST: [0.294 0.636 1.393]
# 14
# | Train_Accuracy: 0.3416666666666667 | COST: [0.285 0.632 1.331]
# 15
# | Train_Accuracy: 0.3416666666666667 | COST: [0.277 0.628 1.272]
# 16
# | Train_Accuracy: 0.3416666666666667 | COST: [0.269 0.624 1.216]
# 17
# | Train_Accuracy: 0.3416666666666667 | COST: [0.262 0.621 1.162]
# 18
# | Train_Accuracy: 0.3416666666666667 | COST: [0.255 0.618 1.111]
# 19
# | Train_Accuracy: 0.35833333333333334 | COST: [0.248 0.615 1.062]
# 20
# | Train_Accuracy: 0.5 | COST: [0.242 0.612 1.016]
# 21
# | Train_Accuracy: 0.5833333333333334 | COST: [0.236 0.609 0.972]
# 22
# | Train_Accuracy: 0.675 | COST: [0.230 0.607 0.931]
# 23
# | Train_Accuracy: 0.6833333333333333 | COST: [0.224 0.604 0.893]
# 24
# | Train_Accuracy: 0.6916666666666667 | COST: [0.219 0.602 0.857]
# 25
# | Train_Accuracy: 0.6833333333333333 | COST: [0.214 0.600 0.824]
# 26
# | Train_Accuracy: 0.6916666666666667 | COST: [0.209 0.598 0.792]
# 27
# | Train_Accuracy: 0.7 | COST: [0.205 0.596 0.763]
# 28
# | Train_Accuracy: 0.7 | COST: [0.200 0.595 0.736]
# 29
# | Train_Accuracy: 0.7166666666666667 | COST: [0.196 0.593 0.710]
# 30
# | Train_Accuracy: 0.7166666666666667 | COST: [0.192 0.591 0.687]
# 31
# | Train_Accuracy: 0.725 | COST: [0.188 0.590 0.665]
# 32
# | Train_Accuracy: 0.725 | COST: [0.184 0.589 0.645]
# 33
# | Train_Accuracy: 0.725 | COST: [0.181 0.587 0.626]
# 34
# | Train_Accuracy: 0.7416666666666667 | COST: [0.177 0.586 0.608]
# 35
# | Train_Accuracy: 0.7583333333333333 | COST: [0.174 0.585 0.592]
# 36
# | Train_Accuracy: 0.7583333333333333 | COST: [0.171 0.584 0.577]
# 37
# | Train_Accuracy: 0.7666666666666667 | COST: [0.167 0.583 0.562]
# 38
# | Train_Accuracy: 0.7666666666666667 | COST: [0.164 0.582 0.549]
# 39
# | Train_Accuracy: 0.775 | COST: [0.162 0.581 0.537]
# 40
# | Train_Accuracy: 0.7916666666666666 | COST: [0.159 0.580 0.525]
# 41
# | Train_Accuracy: 0.8 | COST: [0.156 0.579 0.515]
# 42
# | Train_Accuracy: 0.825 | COST: [0.154 0.579 0.504]
# 43
# | Train_Accuracy: 0.8166666666666667 | COST: [0.151 0.578 0.495]
# 44
# | Train_Accuracy: 0.8166666666666667 | COST: [0.149 0.577 0.486]
# 45
# | Train_Accuracy: 0.8166666666666667 | COST: [0.146 0.576 0.478]
# 46
# | Train_Accuracy: 0.825 | COST: [0.144 0.576 0.470]
# 47
# | Train_Accuracy: 0.825 | COST: [0.142 0.575 0.462]
# 48
# | Train_Accuracy: 0.825 | COST: [0.140 0.575 0.455]
# 49
# | Train_Accuracy: 0.825 | COST: [0.137 0.574 0.449]
# 50
# | Train_Accuracy: 0.8166666666666667 | COST: [0.135 0.574 0.443]
# 51
# | Train_Accuracy: 0.8166666666666667 | COST: [0.134 0.573 0.437]
# 52
# | Train_Accuracy: 0.8166666666666667 | COST: [0.132 0.573 0.431]
# 53
# | Train_Accuracy: 0.8166666666666667 | COST: [0.130 0.572 0.426]
# 54
# | Train_Accuracy: 0.8166666666666667 | COST: [0.128 0.572 0.421]
# 55
# | Train_Accuracy: 0.8166666666666667 | COST: [0.126 0.571 0.416]
# 56
# | Train_Accuracy: 0.8166666666666667 | COST: [0.125 0.571 0.411]
# 57
# | Train_Accuracy: 0.825 | COST: [0.123 0.570 0.407]
# 58
# | Train_Accuracy: 0.825 | COST: [0.121 0.570 0.403]
# 59
# | Train_Accuracy: 0.825 | COST: [0.120 0.570 0.398]
# 60
# | Train_Accuracy: 0.825 | COST: [0.118 0.569 0.395]
# 61
# | Train_Accuracy: 0.825 | COST: [0.117 0.569 0.391]
# 62
# | Train_Accuracy: 0.825 | COST: [0.115 0.568 0.387]
# 63
# | Train_Accuracy: 0.825 | COST: [0.114 0.568 0.384]
# 64
# | Train_Accuracy: 0.825 | COST: [0.112 0.568 0.381]
# 65
# | Train_Accuracy: 0.8333333333333334 | COST: [0.111 0.568 0.378]
# 66
# | Train_Accuracy: 0.8416666666666667 | COST: [0.110 0.567 0.375]
# 67
# | Train_Accuracy: 0.85 | COST: [0.108 0.567 0.372]
# 68
# | Train_Accuracy: 0.85 | COST: [0.107 0.567 0.369]
# 69
# | Train_Accuracy: 0.85 | COST: [0.106 0.566 0.366]
# 70
# | Train_Accuracy: 0.85 | COST: [0.105 0.566 0.363]
# 71
# | Train_Accuracy: 0.85 | COST: [0.104 0.566 0.361]
# 72
# | Train_Accuracy: 0.85 | COST: [0.103 0.566 0.358]
# 73
# | Train_Accuracy: 0.85 | COST: [0.101 0.565 0.356]
# 74
# | Train_Accuracy: 0.85 | COST: [0.100 0.565 0.354]
# 75
# | Train_Accuracy: 0.85 | COST: [0.099 0.565 0.352]
# 76
# | Train_Accuracy: 0.85 | COST: [0.098 0.565 0.349]
# 77
# | Train_Accuracy: 0.85 | COST: [0.097 0.564 0.347]
# 78
# | Train_Accuracy: 0.8583333333333333 | COST: [0.096 0.564 0.345]
# 79
# | Train_Accuracy: 0.8583333333333333 | COST: [0.095 0.564 0.343]
# 80
# | Train_Accuracy: 0.8583333333333333 | COST: [0.094 0.564 0.341]
# 81
# | Train_Accuracy: 0.8583333333333333 | COST: [0.093 0.564 0.340]
# 82
# | Train_Accuracy: 0.8583333333333333 | COST: [0.092 0.563 0.338]
# 83
# | Train_Accuracy: 0.8666666666666667 | COST: [0.091 0.563 0.336]
# 84
# | Train_Accuracy: 0.8666666666666667 | COST: [0.091 0.563 0.334]
# 85
# | Train_Accuracy: 0.8666666666666667 | COST: [0.090 0.563 0.332]
# 86
# | Train_Accuracy: 0.875 | COST: [0.089 0.563 0.331]
# 87
# | Train_Accuracy: 0.875 | COST: [0.088 0.562 0.329]
# 88
# | Train_Accuracy: 0.8833333333333333 | COST: [0.087 0.562 0.328]
# 89
# | Train_Accuracy: 0.8833333333333333 | COST: [0.086 0.562 0.326]
# 90
# | Train_Accuracy: 0.8833333333333333 | COST: [0.086 0.562 0.325]
# 91
# | Train_Accuracy: 0.8916666666666667 | COST: [0.085 0.562 0.323]
# 92
# | Train_Accuracy: 0.8916666666666667 | COST: [0.084 0.562 0.322]
# 93
# | Train_Accuracy: 0.8916666666666667 | COST: [0.083 0.561 0.320]
# 94
# | Train_Accuracy: 0.8916666666666667 | COST: [0.083 0.561 0.319]
# 95
# | Train_Accuracy: 0.8916666666666667 | COST: [0.082 0.561 0.318]
# 96
# | Train_Accuracy: 0.8916666666666667 | COST: [0.081 0.561 0.316]
# 97
# | Train_Accuracy: 0.8916666666666667 | COST: [0.081 0.561 0.315]
# 98
# | Train_Accuracy: 0.8916666666666667 | COST: [0.080 0.561 0.314]
# 99
# | Train_Accuracy: 0.8916666666666667 | COST: [0.079 0.561 0.313]
# 100
# | Train_Accuracy: 0.8916666666666667 | COST: [0.079 0.560 0.311]
# 101
# | Train_Accuracy: 0.8916666666666667 | COST: [0.078 0.560 0.310]
# 102
# | Train_Accuracy: 0.8916666666666667 | COST: [0.077 0.560 0.309]
# 103
# | Train_Accuracy: 0.9 | COST: [0.077 0.560 0.308]
# 104
# | Train_Accuracy: 0.9 | COST: [0.076 0.560 0.307]
# 105
# | Train_Accuracy: 0.9 | COST: [0.075 0.560 0.306]
# 106
# | Train_Accuracy: 0.9 | COST: [0.075 0.559 0.305]
# 107
# | Train_Accuracy: 0.9 | COST: [0.074 0.559 0.304]
# 108
# | Train_Accuracy: 0.9 | COST: [0.074 0.559 0.302]
# 109
# | Train_Accuracy: 0.9 | COST: [0.073 0.559 0.301]
# 110
# | Train_Accuracy: 0.9 | COST: [0.073 0.559 0.300]
# 111
# | Train_Accuracy: 0.9 | COST: [0.072 0.559 0.299]
# 112
# | Train_Accuracy: 0.9 | COST: [0.071 0.559 0.298]
# 113
# | Train_Accuracy: 0.9 | COST: [0.071 0.559 0.297]
# 114
# | Train_Accuracy: 0.9083333333333333 | COST: [0.070 0.558 0.297]
# 115
# | Train_Accuracy: 0.9166666666666666 | COST: [0.070 0.558 0.296]
# 116
# | Train_Accuracy: 0.9166666666666666 | COST: [0.069 0.558 0.295]
# 117
# | Train_Accuracy: 0.9166666666666666 | COST: [0.069 0.558 0.294]
# 118
# | Train_Accuracy: 0.9166666666666666 | COST: [0.068 0.558 0.293]
# 119
# | Train_Accuracy: 0.925 | COST: [0.068 0.558 0.292]
# 120
# | Train_Accuracy: 0.925 | COST: [0.067 0.558 0.291]
# 121
# | Train_Accuracy: 0.925 | COST: [0.067 0.557 0.290]
# 122
# | Train_Accuracy: 0.925 | COST: [0.066 0.557 0.289]
# 123
# | Train_Accuracy: 0.9333333333333333 | COST: [0.066 0.557 0.289]
# 124
# | Train_Accuracy: 0.9333333333333333 | COST: [0.066 0.557 0.288]
# 125
# | Train_Accuracy: 0.9333333333333333 | COST: [0.065 0.557 0.287]
# 126
# | Train_Accuracy: 0.9333333333333333 | COST: [0.065 0.557 0.286]
# 127
# | Train_Accuracy: 0.9333333333333333 | COST: [0.064 0.557 0.285]
# 128
# | Train_Accuracy: 0.9333333333333333 | COST: [0.064 0.557 0.285]
# 129
# | Train_Accuracy: 0.9333333333333333 | COST: [0.063 0.556 0.284]
# 130
# | Train_Accuracy: 0.9333333333333333 | COST: [0.063 0.556 0.283]
# 131
# | Train_Accuracy: 0.9333333333333333 | COST: [0.063 0.556 0.282]
# 132
# | Train_Accuracy: 0.9333333333333333 | COST: [0.062 0.556 0.282]
# 133
# | Train_Accuracy: 0.9333333333333333 | COST: [0.062 0.556 0.281]
# 134
# | Train_Accuracy: 0.9333333333333333 | COST: [0.061 0.556 0.280]
# 135
# | Train_Accuracy: 0.9416666666666667 | COST: [0.061 0.556 0.279]
# 136
# | Train_Accuracy: 0.9416666666666667 | COST: [0.061 0.556 0.279]
# 137
# | Train_Accuracy: 0.9416666666666667 | COST: [0.060 0.556 0.278]
# 138
# | Train_Accuracy: 0.9416666666666667 | COST: [0.060 0.555 0.277]
# 139
# | Train_Accuracy: 0.9416666666666667 | COST: [0.059 0.555 0.277]
# 140
# | Train_Accuracy: 0.9416666666666667 | COST: [0.059 0.555 0.276]
# 141
# | Train_Accuracy: 0.9416666666666667 | COST: [0.059 0.555 0.275]
# 142
# | Train_Accuracy: 0.9416666666666667 | COST: [0.058 0.555 0.275]
# 143
# | Train_Accuracy: 0.9416666666666667 | COST: [0.058 0.555 0.274]
# 144
# | Train_Accuracy: 0.9416666666666667 | COST: [0.058 0.555 0.273]
# 145
# | Train_Accuracy: 0.9416666666666667 | COST: [0.057 0.555 0.273]
# 146
# | Train_Accuracy: 0.95 | COST: [0.057 0.554 0.272]
# 147
# | Train_Accuracy: 0.95 | COST: [0.057 0.554 0.272]
# 148
# | Train_Accuracy: 0.95 | COST: [0.056 0.554 0.271]
# 149
# | Train_Accuracy: 0.95 | COST: [0.056 0.554 0.270]
# 150
# | Train_Accuracy: 0.95 | COST: [0.056 0.554 0.270]
# 151
# | Train_Accuracy: 0.95 | COST: [0.055 0.554 0.269]
# 152
# | Train_Accuracy: 0.95 | COST: [0.055 0.554 0.269]
# 153
# | Train_Accuracy: 0.95 | COST: [0.055 0.554 0.268]
# 154
# | Train_Accuracy: 0.95 | COST: [0.054 0.554 0.267]
# 155
# | Train_Accuracy: 0.95 | COST: [0.054 0.553 0.267]
# 156
# | Train_Accuracy: 0.95 | COST: [0.054 0.553 0.266]
# 157
# | Train_Accuracy: 0.95 | COST: [0.054 0.553 0.266]
# 158
# | Train_Accuracy: 0.95 | COST: [0.053 0.553 0.265]
# 159
# | Train_Accuracy: 0.95 | COST: [0.053 0.553 0.265]
# 160
# | Train_Accuracy: 0.95 | COST: [0.053 0.553 0.264]
# 161
# | Train_Accuracy: 0.95 | COST: [0.052 0.553 0.263]
# 162
# | Train_Accuracy: 0.95 | COST: [0.052 0.553 0.263]
# 163
# | Train_Accuracy: 0.95 | COST: [0.052 0.553 0.262]
# 164
# | Train_Accuracy: 0.95 | COST: [0.052 0.553 0.262]
# 165
# | Train_Accuracy: 0.95 | COST: [0.051 0.552 0.261]
# 166
# | Train_Accuracy: 0.95 | COST: [0.051 0.552 0.261]
# 167
# | Train_Accuracy: 0.95 | COST: [0.051 0.552 0.260]
# 168
# | Train_Accuracy: 0.95 | COST: [0.051 0.552 0.260]
# 169
# | Train_Accuracy: 0.95 | COST: [0.050 0.552 0.259]
# 170
# | Train_Accuracy: 0.95 | COST: [0.050 0.552 0.259]
# 171
# | Train_Accuracy: 0.95 | COST: [0.050 0.552 0.258]
# 172
# | Train_Accuracy: 0.95 | COST: [0.050 0.552 0.258]
# 173
# | Train_Accuracy: 0.95 | COST: [0.049 0.552 0.257]
# 174
# | Train_Accuracy: 0.95 | COST: [0.049 0.551 0.257]
# 175
# | Train_Accuracy: 0.95 | COST: [0.049 0.551 0.256]
# 176
# | Train_Accuracy: 0.95 | COST: [0.049 0.551 0.256]
# 177
# | Train_Accuracy: 0.95 | COST: [0.048 0.551 0.255]
# 178
# | Train_Accuracy: 0.95 | COST: [0.048 0.551 0.255]
# 179
# | Train_Accuracy: 0.95 | COST: [0.048 0.551 0.254]
# 180
# | Train_Accuracy: 0.95 | COST: [0.048 0.551 0.254]
# 181
# | Train_Accuracy: 0.95 | COST: [0.047 0.551 0.254]
# 182
# | Train_Accuracy: 0.95 | COST: [0.047 0.551 0.253]
# 183
# | Train_Accuracy: 0.95 | COST: [0.047 0.551 0.253]
# 184
# | Train_Accuracy: 0.95 | COST: [0.047 0.550 0.252]
# 185
# | Train_Accuracy: 0.95 | COST: [0.046 0.550 0.252]
# 186
# | Train_Accuracy: 0.95 | COST: [0.046 0.550 0.251]
# 187
# | Train_Accuracy: 0.95 | COST: [0.046 0.550 0.251]
# 188
# | Train_Accuracy: 0.95 | COST: [0.046 0.550 0.250]
# 189
# | Train_Accuracy: 0.95 | COST: [0.046 0.550 0.250]
# 190
# | Train_Accuracy: 0.95 | COST: [0.045 0.550 0.250]
# 191
# | Train_Accuracy: 0.95 | COST: [0.045 0.550 0.249]
# 192
# | Train_Accuracy: 0.95 | COST: [0.045 0.550 0.249]
# 193
# | Train_Accuracy: 0.95 | COST: [0.045 0.550 0.248]
# 194
# | Train_Accuracy: 0.95 | COST: [0.045 0.549 0.248]
# 195
# | Train_Accuracy: 0.95 | COST: [0.044 0.549 0.247]
# 196
# | Train_Accuracy: 0.95 | COST: [0.044 0.549 0.247]
# 197
# | Train_Accuracy: 0.95 | COST: [0.044 0.549 0.247]
# 198
# | Train_Accuracy: 0.95 | COST: [0.044 0.549 0.246]
# 199
# | Train_Accuracy: 0.95 | COST: [0.044 0.549 0.246]
# 200
# | Train_Accuracy: 0.95 | COST: [0.043 0.549 0.245]

# %%
# Test Case 정확도
print("-----Test case 정확도-----")
print("target :",reg.accuracy(x_test,y_test))
# Out:
# -----Test case 정확도-----
# target 0: 0.9666666666666667

# %%
x = np.arange(len(reg.train_accuracylist))
plt.plot(x, reg.train_accuracylist, label='train accuracy')
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.1)
plt.legend(loc='lower right')
plt.show()

# %%
x = np.arange(len(reg.train_costlist))
cost = np.array(reg.train_costlist).T
maxcost = cost.max()
plt.plot(x, cost[0], label='train0 cost' ,linestyle='--')
plt.plot(x, cost[1], label='train1 cost',linestyle='--')
plt.plot(x, cost[2], label='train2 cost',linestyle='--')
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, maxcost + 0.1)
plt.legend(loc='lower right')
plt.show()
