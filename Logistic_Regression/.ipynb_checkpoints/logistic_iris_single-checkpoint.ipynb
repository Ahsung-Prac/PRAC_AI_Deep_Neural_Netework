# %%
import matplotlib.pyplot as plt
import numpy as np
import sys, os
sys.path.append(os.pardir)
sys.path.append("../../")
from sklearn.datasets import load_iris
from logisticReg import Lreg
from logisticReg import binaryTarget

# %%
iris = load_iris()
X = iris.data
Y = iris.target
y_name = iris.target_names

# %%
# 인덱스 suffle
suffle_mask = np.random.choice(X.shape[0],X.shape[0],replace=False)
# data 80퍼센트는 Train용, 20퍼센트는 Test용
bound = int(0.8 * X.shape[0])

x_train = X[suffle_mask[:bound]]
x_test = X[suffle_mask[bound:]]
y_train = Y[suffle_mask[:bound]]
y_test = Y[suffle_mask[bound:]]



# binary에 맞는 정답 데이터를 만든다
# multi class의 학습 코드를 재사용하기 위해서, numpy차원을 (data * 1)로 맞춰준다.
y0_train = binaryTarget(y_train,target = 0)
y1_train = binaryTarget(y_train,target = 1)
y2_train = binaryTarget(y_train,target = 2)

y0_test =  binaryTarget(y_test,target = 0)
y1_test =  binaryTarget(y_test,target = 1)
y2_test =  binaryTarget(y_test,target = 2)

# %%
reg0 = Lreg(X.shape[1],y_name.shape[0],"b")
reg1 = Lreg(X.shape[1],y_name.shape[0],"b")
reg2 = Lreg(X.shape[1],y_name.shape[0],"b")

# %%
# 여러 hyper Parmeter로 실험해보기위해
# 매 learning마다 weight를 초기화 해본다.
reg0.reset_weight()
reg1.reset_weight()
reg2.reset_weight()

# class 3개에대한 각 모델 학습시작
reg0.learn(x_train,y0_train,epoch=100,batch_size=x_train.shape[0],lr = 0.03)
reg1.learn(x_train,y1_train,epoch=100,batch_size=x_train.shape[0],lr = 0.03)
reg2.learn(x_train,y2_train,epoch=100,batch_size=x_train.shape[0],lr = 0.03)
# Out:
# Before Learning:
# | Train_Accuracy: 0.008333333333333333 | COST: [4.169]
# 1
# | Train_Accuracy: 0.0 | COST: [3.625]
# 2
# | Train_Accuracy: 0.0 | COST: [3.145]
# 3
# | Train_Accuracy: 0.0 | COST: [2.730]
# 4
# | Train_Accuracy: 0.0 | COST: [2.396]
# 5
# | Train_Accuracy: 0.06666666666666667 | COST: [2.162]
# 6
# | Train_Accuracy: 0.23333333333333334 | COST: [2.019]
# 7
# | Train_Accuracy: 0.325 | COST: [1.936]
# 8
# | Train_Accuracy: 0.39166666666666666 | COST: [1.884]
# 9
# | Train_Accuracy: 0.4583333333333333 | COST: [1.847]
# 10
# | Train_Accuracy: 0.49166666666666664 | COST: [1.816]
# 11
# | Train_Accuracy: 0.5083333333333333 | COST: [1.787]
# 12
# | Train_Accuracy: 0.5416666666666666 | COST: [1.760]
# 13
# | Train_Accuracy: 0.5583333333333333 | COST: [1.734]
# 14
# | Train_Accuracy: 0.575 | COST: [1.708]
# 15
# | Train_Accuracy: 0.5833333333333334 | COST: [1.682]
# 16
# | Train_Accuracy: 0.6 | COST: [1.657]
# 17
# | Train_Accuracy: 0.6 | COST: [1.631]
# 18
# | Train_Accuracy: 0.6083333333333333 | COST: [1.606]
# 19
# | Train_Accuracy: 0.6083333333333333 | COST: [1.580]
# 20
# | Train_Accuracy: 0.6166666666666667 | COST: [1.555]
# 21
# | Train_Accuracy: 0.6166666666666667 | COST: [1.530]
# 22
# | Train_Accuracy: 0.6166666666666667 | COST: [1.505]
# 23
# | Train_Accuracy: 0.6333333333333333 | COST: [1.480]
# 24
# | Train_Accuracy: 0.6416666666666667 | COST: [1.456]
# 25
# | Train_Accuracy: 0.6416666666666667 | COST: [1.431]
# 26
# | Train_Accuracy: 0.65 | COST: [1.407]
# 27
# | Train_Accuracy: 0.65 | COST: [1.383]
# 28
# | Train_Accuracy: 0.65 | COST: [1.359]
# 29
# | Train_Accuracy: 0.65 | COST: [1.335]
# 30
# | Train_Accuracy: 0.65 | COST: [1.311]
# 31
# | Train_Accuracy: 0.65 | COST: [1.288]
# 32
# | Train_Accuracy: 0.65 | COST: [1.265]
# 33
# | Train_Accuracy: 0.65 | COST: [1.242]
# 34
# | Train_Accuracy: 0.65 | COST: [1.219]
# 35
# | Train_Accuracy: 0.65 | COST: [1.196]
# 36
# | Train_Accuracy: 0.65 | COST: [1.174]
# 37
# | Train_Accuracy: 0.65 | COST: [1.152]
# 38
# | Train_Accuracy: 0.6583333333333333 | COST: [1.130]
# 39
# | Train_Accuracy: 0.6583333333333333 | COST: [1.108]
# 40
# | Train_Accuracy: 0.6583333333333333 | COST: [1.087]
# 41
# | Train_Accuracy: 0.6583333333333333 | COST: [1.066]
# 42
# | Train_Accuracy: 0.6583333333333333 | COST: [1.045]
# 43
# | Train_Accuracy: 0.6583333333333333 | COST: [1.024]
# 44
# | Train_Accuracy: 0.6583333333333333 | COST: [1.004]
# 45
# | Train_Accuracy: 0.6583333333333333 | COST: [0.984]
# 46
# | Train_Accuracy: 0.6583333333333333 | COST: [0.964]
# 47
# | Train_Accuracy: 0.6583333333333333 | COST: [0.945]
# 48
# | Train_Accuracy: 0.6583333333333333 | COST: [0.926]
# 49
# | Train_Accuracy: 0.6583333333333333 | COST: [0.907]
# 50
# | Train_Accuracy: 0.6583333333333333 | COST: [0.888]
# 51
# | Train_Accuracy: 0.6583333333333333 | COST: [0.870]
# 52
# | Train_Accuracy: 0.6583333333333333 | COST: [0.852]
# 53
# | Train_Accuracy: 0.6583333333333333 | COST: [0.835]
# 54
# | Train_Accuracy: 0.6583333333333333 | COST: [0.818]
# 55
# | Train_Accuracy: 0.6583333333333333 | COST: [0.801]
# 56
# | Train_Accuracy: 0.6583333333333333 | COST: [0.785]
# 57
# | Train_Accuracy: 0.6583333333333333 | COST: [0.769]
# 58
# | Train_Accuracy: 0.6583333333333333 | COST: [0.753]
# 59
# | Train_Accuracy: 0.6583333333333333 | COST: [0.737]
# 60
# | Train_Accuracy: 0.6583333333333333 | COST: [0.722]
# 61
# | Train_Accuracy: 0.6583333333333333 | COST: [0.707]
# 62
# | Train_Accuracy: 0.6583333333333333 | COST: [0.693]
# 63
# | Train_Accuracy: 0.6583333333333333 | COST: [0.679]
# 64
# | Train_Accuracy: 0.6583333333333333 | COST: [0.665]
# 65
# | Train_Accuracy: 0.6583333333333333 | COST: [0.652]
# 66
# | Train_Accuracy: 0.6583333333333333 | COST: [0.639]
# 67
# | Train_Accuracy: 0.6583333333333333 | COST: [0.626]
# 68
# | Train_Accuracy: 0.6583333333333333 | COST: [0.614]
# 69
# | Train_Accuracy: 0.6583333333333333 | COST: [0.601]
# 70
# | Train_Accuracy: 0.6583333333333333 | COST: [0.590]
# 71
# | Train_Accuracy: 0.6583333333333333 | COST: [0.578]
# 72
# | Train_Accuracy: 0.6583333333333333 | COST: [0.567]
# 73
# | Train_Accuracy: 0.6583333333333333 | COST: [0.556]
# 74
# | Train_Accuracy: 0.6583333333333333 | COST: [0.545]
# 75
# | Train_Accuracy: 0.6583333333333333 | COST: [0.535]
# 76
# | Train_Accuracy: 0.6583333333333333 | COST: [0.525]
# 77
# | Train_Accuracy: 0.6583333333333333 | COST: [0.515]
# 78
# | Train_Accuracy: 0.6666666666666666 | COST: [0.506]
# 79
# | Train_Accuracy: 0.6666666666666666 | COST: [0.496]
# 80
# | Train_Accuracy: 0.6666666666666666 | COST: [0.487]
# 81
# | Train_Accuracy: 0.6666666666666666 | COST: [0.478]
# 82
# | Train_Accuracy: 0.6666666666666666 | COST: [0.470]
# 83
# | Train_Accuracy: 0.6666666666666666 | COST: [0.461]
# 84
# | Train_Accuracy: 0.6666666666666666 | COST: [0.453]
# 85
# | Train_Accuracy: 0.6666666666666666 | COST: [0.445]
# 86
# | Train_Accuracy: 0.6666666666666666 | COST: [0.438]
# 87
# | Train_Accuracy: 0.6666666666666666 | COST: [0.430]
# 88
# | Train_Accuracy: 0.675 | COST: [0.423]
# 89
# | Train_Accuracy: 0.6833333333333333 | COST: [0.416]
# 90
# | Train_Accuracy: 0.7166666666666667 | COST: [0.409]
# 91
# | Train_Accuracy: 0.7166666666666667 | COST: [0.402]
# 92
# | Train_Accuracy: 0.7416666666666667 | COST: [0.396]
# 93
# | Train_Accuracy: 0.775 | COST: [0.389]
# 94
# | Train_Accuracy: 0.8 | COST: [0.383]
# 95
# | Train_Accuracy: 0.8166666666666667 | COST: [0.377]
# 96
# | Train_Accuracy: 0.8333333333333334 | COST: [0.371]
# 97
# | Train_Accuracy: 0.8916666666666667 | COST: [0.365]
# 98
# | Train_Accuracy: 0.9166666666666666 | COST: [0.360]
# 99
# | Train_Accuracy: 0.9333333333333333 | COST: [0.354]
# 100
# | Train_Accuracy: 0.9666666666666667 | COST: [0.349]
# Before Learning:
# | Train_Accuracy: 0.3416666666666667 | COST: [3.694]
# 1
# | Train_Accuracy: 0.3416666666666667 | COST: [2.967]
# 2
# | Train_Accuracy: 0.3416666666666667 | COST: [2.264]
# 3
# | Train_Accuracy: 0.3416666666666667 | COST: [1.631]
# 4
# | Train_Accuracy: 0.3416666666666667 | COST: [1.159]
# 5
# | Train_Accuracy: 0.5333333333333333 | COST: [0.910]
# 6
# | Train_Accuracy: 0.45 | COST: [0.815]
# 7
# | Train_Accuracy: 0.35 | COST: [0.780]
# 8
# | Train_Accuracy: 0.325 | COST: [0.764]
# 9
# | Train_Accuracy: 0.31666666666666665 | COST: [0.755]
# 10
# | Train_Accuracy: 0.31666666666666665 | COST: [0.748]
# 11
# | Train_Accuracy: 0.325 | COST: [0.743]
# 12
# | Train_Accuracy: 0.325 | COST: [0.738]
# 13
# | Train_Accuracy: 0.3416666666666667 | COST: [0.733]
# 14
# | Train_Accuracy: 0.35 | COST: [0.728]
# 15
# | Train_Accuracy: 0.35833333333333334 | COST: [0.724]
# 16
# | Train_Accuracy: 0.36666666666666664 | COST: [0.720]
# 17
# | Train_Accuracy: 0.36666666666666664 | COST: [0.715]
# 18
# | Train_Accuracy: 0.375 | COST: [0.711]
# 19
# | Train_Accuracy: 0.4 | COST: [0.707]
# 20
# | Train_Accuracy: 0.4166666666666667 | COST: [0.704]
# 21
# | Train_Accuracy: 0.45 | COST: [0.700]
# 22
# | Train_Accuracy: 0.475 | COST: [0.696]
# 23
# | Train_Accuracy: 0.5166666666666667 | COST: [0.693]
# 24
# | Train_Accuracy: 0.5333333333333333 | COST: [0.689]
# 25
# | Train_Accuracy: 0.5333333333333333 | COST: [0.686]
# 26
# | Train_Accuracy: 0.5333333333333333 | COST: [0.683]
# 27
# | Train_Accuracy: 0.5583333333333333 | COST: [0.680]
# 28
# | Train_Accuracy: 0.5666666666666667 | COST: [0.677]
# 29
# | Train_Accuracy: 0.5916666666666667 | COST: [0.674]
# 30
# | Train_Accuracy: 0.6 | COST: [0.671]
# 31
# | Train_Accuracy: 0.6166666666666667 | COST: [0.668]
# 32
# | Train_Accuracy: 0.625 | COST: [0.665]
# 33
# | Train_Accuracy: 0.6416666666666667 | COST: [0.663]
# 34
# | Train_Accuracy: 0.65 | COST: [0.660]
# 35
# | Train_Accuracy: 0.65 | COST: [0.658]
# 36
# | Train_Accuracy: 0.65 | COST: [0.655]
# 37
# | Train_Accuracy: 0.65 | COST: [0.653]
# 38
# | Train_Accuracy: 0.65 | COST: [0.651]
# 39
# | Train_Accuracy: 0.65 | COST: [0.649]
# 40
# | Train_Accuracy: 0.65 | COST: [0.646]
# 41
# | Train_Accuracy: 0.65 | COST: [0.644]
# 42
# | Train_Accuracy: 0.65 | COST: [0.642]
# 43
# | Train_Accuracy: 0.65 | COST: [0.640]
# 44
# | Train_Accuracy: 0.65 | COST: [0.639]
# 45
# | Train_Accuracy: 0.65 | COST: [0.637]
# 46
# | Train_Accuracy: 0.65 | COST: [0.635]
# 47
# | Train_Accuracy: 0.65 | COST: [0.633]
# 48
# | Train_Accuracy: 0.65 | COST: [0.632]
# 49
# | Train_Accuracy: 0.65 | COST: [0.630]
# 50
# | Train_Accuracy: 0.65 | COST: [0.628]
# 51
# | Train_Accuracy: 0.65 | COST: [0.627]
# 52
# | Train_Accuracy: 0.65 | COST: [0.625]
# 53
# | Train_Accuracy: 0.65 | COST: [0.624]
# 54
# | Train_Accuracy: 0.65 | COST: [0.622]
# 55
# | Train_Accuracy: 0.65 | COST: [0.621]
# 56
# | Train_Accuracy: 0.65 | COST: [0.620]
# 57
# | Train_Accuracy: 0.65 | COST: [0.618]
# 58
# | Train_Accuracy: 0.65 | COST: [0.617]
# 59
# | Train_Accuracy: 0.65 | COST: [0.616]
# 60
# | Train_Accuracy: 0.65 | COST: [0.615]
# 61
# | Train_Accuracy: 0.65 | COST: [0.614]
# 62
# | Train_Accuracy: 0.65 | COST: [0.613]
# 63
# | Train_Accuracy: 0.65 | COST: [0.611]
# 64
# | Train_Accuracy: 0.65 | COST: [0.610]
# 65
# | Train_Accuracy: 0.65 | COST: [0.609]
# 66
# | Train_Accuracy: 0.65 | COST: [0.608]
# 67
# | Train_Accuracy: 0.6583333333333333 | COST: [0.607]
# 68
# | Train_Accuracy: 0.6583333333333333 | COST: [0.606]
# 69
# | Train_Accuracy: 0.6583333333333333 | COST: [0.605]
# 70
# | Train_Accuracy: 0.6583333333333333 | COST: [0.605]
# 71
# | Train_Accuracy: 0.6583333333333333 | COST: [0.604]
# 72
# | Train_Accuracy: 0.6583333333333333 | COST: [0.603]
# 73
# | Train_Accuracy: 0.6583333333333333 | COST: [0.602]
# 74
# | Train_Accuracy: 0.6583333333333333 | COST: [0.601]
# 75
# | Train_Accuracy: 0.6583333333333333 | COST: [0.600]
# 76
# | Train_Accuracy: 0.6583333333333333 | COST: [0.600]
# 77
# | Train_Accuracy: 0.6666666666666666 | COST: [0.599]
# 78
# | Train_Accuracy: 0.6666666666666666 | COST: [0.598]
# 79
# | Train_Accuracy: 0.6666666666666666 | COST: [0.597]
# 80
# | Train_Accuracy: 0.6666666666666666 | COST: [0.597]
# 81
# | Train_Accuracy: 0.6666666666666666 | COST: [0.596]
# 82
# | Train_Accuracy: 0.6666666666666666 | COST: [0.595]
# 83
# | Train_Accuracy: 0.6666666666666666 | COST: [0.595]
# 84
# | Train_Accuracy: 0.6666666666666666 | COST: [0.594]
# 85
# | Train_Accuracy: 0.6666666666666666 | COST: [0.594]
# 86
# | Train_Accuracy: 0.6666666666666666 | COST: [0.593]
# 87
# | Train_Accuracy: 0.6666666666666666 | COST: [0.592]
# 88
# | Train_Accuracy: 0.6666666666666666 | COST: [0.592]
# 89
# | Train_Accuracy: 0.6666666666666666 | COST: [0.591]
# 90
# | Train_Accuracy: 0.6666666666666666 | COST: [0.591]
# 91
# | Train_Accuracy: 0.6666666666666666 | COST: [0.590]
# 92
# | Train_Accuracy: 0.6666666666666666 | COST: [0.590]
# 93
# | Train_Accuracy: 0.6666666666666666 | COST: [0.589]
# 94
# | Train_Accuracy: 0.6666666666666666 | COST: [0.589]
# 95
# | Train_Accuracy: 0.6666666666666666 | COST: [0.588]
# 96
# | Train_Accuracy: 0.6666666666666666 | COST: [0.588]
# 97
# | Train_Accuracy: 0.675 | COST: [0.587]
# 98
# | Train_Accuracy: 0.675 | COST: [0.587]
# 99
# | Train_Accuracy: 0.6666666666666666 | COST: [0.586]
# 100
# | Train_Accuracy: 0.6666666666666666 | COST: [0.586]
# Before Learning:
# | Train_Accuracy: 0.31666666666666665 | COST: [2.894]
# 1
# | Train_Accuracy: 0.31666666666666665 | COST: [2.237]
# 2
# | Train_Accuracy: 0.31666666666666665 | COST: [1.639]
# 3
# | Train_Accuracy: 0.31666666666666665 | COST: [1.166]
# 4
# | Train_Accuracy: 0.3 | COST: [0.879]
# 5
# | Train_Accuracy: 0.4083333333333333 | COST: [0.755]
# 6
# | Train_Accuracy: 0.5 | COST: [0.710]
# 7
# | Train_Accuracy: 0.6 | COST: [0.692]
# 8
# | Train_Accuracy: 0.6166666666666667 | COST: [0.682]
# 9
# | Train_Accuracy: 0.6333333333333333 | COST: [0.675]
# 10
# | Train_Accuracy: 0.6666666666666666 | COST: [0.668]
# 11
# | Train_Accuracy: 0.675 | COST: [0.663]
# 12
# | Train_Accuracy: 0.6833333333333333 | COST: [0.657]
# 13
# | Train_Accuracy: 0.6833333333333333 | COST: [0.652]
# 14
# | Train_Accuracy: 0.6833333333333333 | COST: [0.646]
# 15
# | Train_Accuracy: 0.6916666666666667 | COST: [0.641]
# 16
# | Train_Accuracy: 0.6916666666666667 | COST: [0.636]
# 17
# | Train_Accuracy: 0.6916666666666667 | COST: [0.631]
# 18
# | Train_Accuracy: 0.7 | COST: [0.627]
# 19
# | Train_Accuracy: 0.6916666666666667 | COST: [0.622]
# 20
# | Train_Accuracy: 0.6916666666666667 | COST: [0.617]
# 21
# | Train_Accuracy: 0.6916666666666667 | COST: [0.613]
# 22
# | Train_Accuracy: 0.675 | COST: [0.609]
# 23
# | Train_Accuracy: 0.675 | COST: [0.605]
# 24
# | Train_Accuracy: 0.675 | COST: [0.601]
# 25
# | Train_Accuracy: 0.675 | COST: [0.597]
# 26
# | Train_Accuracy: 0.675 | COST: [0.593]
# 27
# | Train_Accuracy: 0.675 | COST: [0.589]
# 28
# | Train_Accuracy: 0.675 | COST: [0.585]
# 29
# | Train_Accuracy: 0.675 | COST: [0.582]
# 30
# | Train_Accuracy: 0.675 | COST: [0.578]
# 31
# | Train_Accuracy: 0.675 | COST: [0.575]
# 32
# | Train_Accuracy: 0.6833333333333333 | COST: [0.571]
# 33
# | Train_Accuracy: 0.6916666666666667 | COST: [0.568]
# 34
# | Train_Accuracy: 0.6916666666666667 | COST: [0.565]
# 35
# | Train_Accuracy: 0.6916666666666667 | COST: [0.562]
# 36
# | Train_Accuracy: 0.6916666666666667 | COST: [0.559]
# 37
# | Train_Accuracy: 0.6916666666666667 | COST: [0.556]
# 38
# | Train_Accuracy: 0.7083333333333334 | COST: [0.553]
# 39
# | Train_Accuracy: 0.7083333333333334 | COST: [0.550]
# 40
# | Train_Accuracy: 0.7083333333333334 | COST: [0.547]
# 41
# | Train_Accuracy: 0.7 | COST: [0.544]
# 42
# | Train_Accuracy: 0.7 | COST: [0.542]
# 43
# | Train_Accuracy: 0.7 | COST: [0.539]
# 44
# | Train_Accuracy: 0.7 | COST: [0.537]
# 45
# | Train_Accuracy: 0.7 | COST: [0.534]
# 46
# | Train_Accuracy: 0.7 | COST: [0.532]
# 47
# | Train_Accuracy: 0.7 | COST: [0.529]
# 48
# | Train_Accuracy: 0.7 | COST: [0.527]
# 49
# | Train_Accuracy: 0.7083333333333334 | COST: [0.524]
# 50
# | Train_Accuracy: 0.7083333333333334 | COST: [0.522]
# 51
# | Train_Accuracy: 0.7083333333333334 | COST: [0.520]
# 52
# | Train_Accuracy: 0.7083333333333334 | COST: [0.518]
# 53
# | Train_Accuracy: 0.7083333333333334 | COST: [0.515]
# 54
# | Train_Accuracy: 0.7083333333333334 | COST: [0.513]
# 55
# | Train_Accuracy: 0.7083333333333334 | COST: [0.511]
# 56
# | Train_Accuracy: 0.7083333333333334 | COST: [0.509]
# 57
# | Train_Accuracy: 0.7083333333333334 | COST: [0.507]
# 58
# | Train_Accuracy: 0.7166666666666667 | COST: [0.505]
# 59
# | Train_Accuracy: 0.7166666666666667 | COST: [0.503]
# 60
# | Train_Accuracy: 0.7166666666666667 | COST: [0.501]
# 61
# | Train_Accuracy: 0.7166666666666667 | COST: [0.499]
# 62
# | Train_Accuracy: 0.7166666666666667 | COST: [0.498]
# 63
# | Train_Accuracy: 0.7166666666666667 | COST: [0.496]
# 64
# | Train_Accuracy: 0.7166666666666667 | COST: [0.494]
# 65
# | Train_Accuracy: 0.7166666666666667 | COST: [0.492]
# 66
# | Train_Accuracy: 0.7333333333333333 | COST: [0.490]
# 67
# | Train_Accuracy: 0.7333333333333333 | COST: [0.489]
# 68
# | Train_Accuracy: 0.7333333333333333 | COST: [0.487]
# 69
# | Train_Accuracy: 0.7333333333333333 | COST: [0.485]
# 70
# | Train_Accuracy: 0.7333333333333333 | COST: [0.484]
# 71
# | Train_Accuracy: 0.7333333333333333 | COST: [0.482]
# 72
# | Train_Accuracy: 0.7333333333333333 | COST: [0.481]
# 73
# | Train_Accuracy: 0.7416666666666667 | COST: [0.479]
# 74
# | Train_Accuracy: 0.7416666666666667 | COST: [0.478]
# 75
# | Train_Accuracy: 0.75 | COST: [0.476]
# 76
# | Train_Accuracy: 0.75 | COST: [0.475]
# 77
# | Train_Accuracy: 0.75 | COST: [0.473]
# 78
# | Train_Accuracy: 0.75 | COST: [0.472]
# 79
# | Train_Accuracy: 0.75 | COST: [0.470]
# 80
# | Train_Accuracy: 0.7666666666666667 | COST: [0.469]
# 81
# | Train_Accuracy: 0.7666666666666667 | COST: [0.467]
# 82
# | Train_Accuracy: 0.7666666666666667 | COST: [0.466]
# 83
# | Train_Accuracy: 0.7666666666666667 | COST: [0.465]
# 84
# | Train_Accuracy: 0.7666666666666667 | COST: [0.463]
# 85
# | Train_Accuracy: 0.7666666666666667 | COST: [0.462]
# 86
# | Train_Accuracy: 0.7666666666666667 | COST: [0.461]
# 87
# | Train_Accuracy: 0.7666666666666667 | COST: [0.460]
# 88
# | Train_Accuracy: 0.7666666666666667 | COST: [0.458]
# 89
# | Train_Accuracy: 0.7666666666666667 | COST: [0.457]
# 90
# | Train_Accuracy: 0.7666666666666667 | COST: [0.456]
# 91
# | Train_Accuracy: 0.7666666666666667 | COST: [0.455]
# 92
# | Train_Accuracy: 0.7666666666666667 | COST: [0.453]
# 93
# | Train_Accuracy: 0.7666666666666667 | COST: [0.452]
# 94
# | Train_Accuracy: 0.7666666666666667 | COST: [0.451]
# 95
# | Train_Accuracy: 0.7666666666666667 | COST: [0.450]
# 96
# | Train_Accuracy: 0.775 | COST: [0.449]
# 97
# | Train_Accuracy: 0.7833333333333333 | COST: [0.448]
# 98
# | Train_Accuracy: 0.7833333333333333 | COST: [0.447]
# 99
# | Train_Accuracy: 0.7833333333333333 | COST: [0.445]
# 100
# | Train_Accuracy: 0.7833333333333333 | COST: [0.444]

# %%
# Test Case 정확도
print("-----Test case 정확도-----")
print("target 0:",reg0.accuracy(x_test,y0_test))
print("target 1:",reg1.accuracy(x_test,y1_test))
print("target 2:",reg2.accuracy(x_test,y2_test))
# Out:
# -----Test case 정확도-----
# target 0: 0.9
# target 1: 0.7333333333333333
# target 2: 0.7333333333333333

# %%
x = np.arange(len(reg0.train_accuracylist))
plt.plot(x, reg0.train_accuracylist, label='0 test accuracy', linestyle='--')
plt.plot(x, reg1.train_accuracylist, label='1 test accuracy', linestyle='--')
plt.plot(x, reg2.train_accuracylist, label='2 test accuracy', linestyle='--')
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.1)
plt.legend(loc='lower right')
plt.show()

# %%
maxlist = [max(reg0.train_costlist),max(reg1.train_costlist),max(reg2.train_costlist)]
maxcost = max(maxlist)
x = np.arange(len(reg0.train_costlist))
plt.plot(x, reg0.train_costlist, label='0 train cost', linestyle='--')
plt.plot(x, reg1.train_costlist, label='1 train cost', linestyle='--')
plt.plot(x, reg2.train_costlist, label='2 train cost', linestyle='--')
plt.xlabel("epochs")
plt.ylabel("Cost")
plt.ylim(0,maxcost+0.1)
plt.legend(loc='lower right')
plt.show()
